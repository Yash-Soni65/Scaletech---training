# %%
import pandas as pd

df= pd.read_csv("Ecommerce_Sales_Data_2024_2025.csv")
df.head()
df.tail()
df.shape
df.columns
df.dtypes
# Out:
# Order ID           int64
# Order Date           str
# Customer Name        str
# Region               str
# City                 str
# Category             str
# Sub-Category         str
# Product Name         str
# Quantity           int64
# Unit Price         int64
# Discount           int64
# Sales            float64
# Profit           float64
# Payment Mode         str
# dtype: object

# %%
df["Sales"].mean()
# Out:
# np.float64(106733.20487)

# %%
df["revenue"] = df["Unit Price"] * df["Quantity"]
print(df[["revenue","Unit Price","Quantity"]])
# Out:
#       revenue  Unit Price  Quantity
# 0       72588       36294         2
# 1       42165       42165         1
# 2      259504       64876         4
# 3      186600       37320         5
# 4       50037       50037         1
# ...       ...         ...       ...
# 4995   182013       60671         3
# 4996   350240       70048         5
# 4997    42162       42162         1
# 4998    54272       13568         4
# 4999    76762       76762         1
#
# [5000 rows x 3 columns]

# %%
print(df["revenue"]>100000)
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 4995     True
# 4996     True
# 4997    False
# 4998    False
# 4999    False
# Name: revenue, Length: 5000, dtype: bool

# %%
df.groupby("City")["revenue"].sum()
# Out:
# City
# Ahmedabad             27865848
# Amritsar              31943123
# Bangalore             33232783
# Bhubaneswar           30029791
# Chandigarh            32946991
# Chennai               27756128
# Coimbatore            26226416
# Delhi                 29660002
# Goa                   29771376
# Guwahati              33075280
# Hyderabad             27076497
# Jaipur                32736036
# Kolkata               27136873
# Lucknow               33014178
# Mumbai                27084824
# Patna                 30609756
# Pune                  29178043
# Ranchi                29990378
# Surat                 31266747
# Thiruvananthapuram    22570019
# Name: revenue, dtype: int64

# %%
df.sort_values("revenue", ascending=False)
# Out:
#       Order ID  Order Date    Customer Name Region         City    Category  \
# 2179     12180  2025-09-13     Hazel Barman   East        Patna    Clothing
# 1730     11731  2024-09-23       Lagan Bora   East     Guwahati  Home Decor
# 3332     13333  2025-02-07      Rohan Khare   West        Surat      Sports
# 2960     12961  2025-09-08     Raunak Atwal  South    Hyderabad    Clothing
# 29       10030  2024-04-22   Adira Seshadri  North   Chandigarh   Groceries
# ...        ...         ...              ...    ...          ...         ...
# 2903     12904  2024-04-07    Umang Goswami   East  Bhubaneswar   Furniture
# 1132     11133  2024-08-23   Ahana  Rastogi  South      Chennai        Toys
# 3059     13060  2024-03-16   Jiya Chaudhary   East        Patna       Books
# 4099     14100  2024-08-25   Trisha Goswami   West          Goa      Beauty
# 3065     13066  2024-11-04  Gatik Chaudhary   East        Patna   Furniture
#
# ...

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Customer Name    0
# Region           0
# City             0
# Category         0
# Sub-Category     0
# Product Name     0
# Quantity         0
# Unit Price       0
# Discount         0
# Sales            0
# Profit           0
# Payment Mode     0
# revenue          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("sales_analysis.csv", index=False)
